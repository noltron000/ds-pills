# %% [markdown]
# # Opioids in the USA
# > Source: [The Washington Post](https://www.kaggle.com/paultimothymooney/pain-pills-in-the-usa/kernels)

# %% [markdown]
# ## Notebook Setup

# %%
import pandas as pd 
import dask.dataframe as dd
import os
from tqdm import tqdm

# %%
# the dataset that we're using is 80GB
# check out this resource
# https://www.kaggle.com/szelee/how-to-import-a-csv-file-of-55-million-rows
path = '../data/arcos_all_washpost.tsv'

# %% [markdown]
# ## Explore Data

# %%
# peep at the data
temp_data = pd.read_csv(path, nrows=15, sep='\t')

# %%
# check out column names
for column in temp_data.columns:
	print(column)
# Out:
# REPORTER_DEA_NO
# REPORTER_BUS_ACT
# REPORTER_NAME
# REPORTER_ADDL_CO_INFO
# REPORTER_ADDRESS1
# REPORTER_ADDRESS2
# REPORTER_CITY
# REPORTER_STATE
# REPORTER_ZIP
# REPORTER_COUNTY
# BUYER_DEA_NO
# BUYER_BUS_ACT
# BUYER_NAME
# BUYER_ADDL_CO_INFO
# BUYER_ADDRESS1
# BUYER_ADDRESS2
# BUYER_CITY
# BUYER_STATE
# BUYER_ZIP
# BUYER_COUNTY
# TRANSACTION_CODE
# DRUG_CODE
# NDC_NO
# DRUG_NAME
# QUANTITY
# UNIT
# ACTION_INDICATOR
# ORDER_FORM_NO
# CORRECTION_NO
# STRENGTH
# TRANSACTION_DATE
# CALC_BASE_WT_IN_GM
# DOSAGE_UNIT
# TRANSACTION_ID
# Product_Name
# Ingredient_Name
# Measure
# MME_Conversion_Factor
# Combined_Labeler_Name
# Revised_Company_Name
# Reporter_family
# dos_str

# %%
# get a feel for each column's data type
temp_data.T
# Out:
#                                                             0   \
# REPORTER_DEA_NO                                      PA0006836
# REPORTER_BUS_ACT                                   DISTRIBUTOR
# REPORTER_NAME                       ACE SURGICAL SUPPLY CO INC
# REPORTER_ADDL_CO_INFO                                      NaN
# REPORTER_ADDRESS1                            1034 PEARL STREET
# REPORTER_ADDRESS2                                          NaN
# REPORTER_CITY                                         BROCKTON
# REPORTER_STATE                                              MA
# REPORTER_ZIP                                              2301
# REPORTER_COUNTY                                       PLYMOUTH
# BUYER_DEA_NO                                         BT3484653
# BUYER_BUS_ACT                                     PRACTITIONER
# BUYER_NAME                                TABRIZI, HAMID R DMD
# BUYER_ADDL_CO_INFO                                         NaN
# BUYER_ADDRESS1                      389 MAIN STREET, SUITE 404
# BUYER_ADDRESS2                                             NaN
# BUYER_CITY                                              MALDEN
# BUYER_STATE                                                 MA
# BUYER_ZIP                                                 2148
# BUYER_COUNTY                                         MIDDLESEX
# TRANSACTION_CODE                                             S
# DRUG_CODE                                                 9193
# NDC_NO                                               406036301
# DRUG_NAME                                          HYDROCODONE
# QUANTITY                                                     1
# UNIT                                                       NaN
# ACTION_INDICATOR                                           NaN
# ORDER_FORM_NO                                              NaN
# CORRECTION_NO                                              NaN
# STRENGTH                                                   NaN
# TRANSACTION_DATE                                      12262012
# CALC_BASE_WT_IN_GM                                      0.6054
# DOSAGE_UNIT                                                100
# TRANSACTION_ID                                              64
# Product_Name              HYDROCODONE BIT/ACETA 10MG/500MG USP
# Ingredient_Name        HYDROCODONE BITARTRATE HEMIPENTAHYDRATE
# Measure                                                    TAB
# MME_Conversion_Factor                                        1
# Combined_Labeler_Name                               SpecGx LLC
# Revised_Company_Name                              Mallinckrodt
# Reporter_family                     ACE Surgical Supply Co Inc
# dos_str                                                     10
# reporter id                                          PA0006836
#
#                                                             1   \
# REPORTER_DEA_NO                                      PA0021179
# REPORTER_BUS_ACT                                   DISTRIBUTOR
# REPORTER_NAME                                     APOTHECA INC
# REPORTER_ADDL_CO_INFO                                      NaN
# REPORTER_ADDRESS1                               1622 N 16TH ST
# REPORTER_ADDRESS2                                          NaN
# REPORTER_CITY                                          PHOENIX
# REPORTER_STATE                                              AZ
# REPORTER_ZIP                                             85006
# REPORTER_COUNTY                                       MARICOPA
# BUYER_DEA_NO                                         BA9740019
# BUYER_BUS_ACT                                  RETAIL PHARMACY
# BUYER_NAME                         APOTHECARY SHOP DEER VALLEY
# BUYER_ADDL_CO_INFO                                         NaN
# BUYER_ADDRESS1                                 23620 N 20TH DR
# BUYER_ADDRESS2                                             #12
# BUYER_CITY                                             PHOENIX
# BUYER_STATE                                                 AZ
# BUYER_ZIP                                                85085
# BUYER_COUNTY                                          MARICOPA
# TRANSACTION_CODE                                             S
# DRUG_CODE                                                 9193
# NDC_NO                                             12634051400
# DRUG_NAME                                          HYDROCODONE
# QUANTITY                                                     4
# UNIT                                                       NaN
# ACTION_INDICATOR                                           NaN
# ORDER_FORM_NO                                              NaN
# CORRECTION_NO                                              NaN
# STRENGTH                                                   NaN
# TRANSACTION_DATE                                       3112009
# CALC_BASE_WT_IN_GM                                     0.12108
# DOSAGE_UNIT                                                 40
# TRANSACTION_ID                                              52
# Product_Name              HYDROCODONE BITARTRATE & ACETA  5MG/
# Ingredient_Name        HYDROCODONE BITARTRATE HEMIPENTAHYDRATE
# Measure                                                    TAB
# MME_Conversion_Factor                                        1
# Combined_Labeler_Name                            Apotheca Inc.
# Revised_Company_Name                             Apotheca Inc.
# Reporter_family                                   Apotheca Inc
# dos_str                                                      5
# reporter id                                          PA0021179
#
#                                                             2   \
# REPORTER_DEA_NO                                      PA0021179
# REPORTER_BUS_ACT                                   DISTRIBUTOR
# REPORTER_NAME                                     APOTHECA INC
# REPORTER_ADDL_CO_INFO                                      NaN
# REPORTER_ADDRESS1                               1622 N 16TH ST
# REPORTER_ADDRESS2                                          NaN
# REPORTER_CITY                                          PHOENIX
# REPORTER_STATE                                              AZ
# REPORTER_ZIP                                             85006
# REPORTER_COUNTY                                       MARICOPA
# BUYER_DEA_NO                                         BH5651155
# BUYER_BUS_ACT                                     PRACTITIONER
# BUYER_NAME                             HOBBS, DOUGLAS DON,  MD
# BUYER_ADDL_CO_INFO                                         NaN
# BUYER_ADDRESS1                        URGENT CARE EXTRA COOPER
# BUYER_ADDRESS2                                 641 WEST WARNER
# BUYER_CITY                                             GILBERT
# BUYER_STATE                                                 AZ
# BUYER_ZIP                                                85233
# BUYER_COUNTY                                          MARICOPA
# TRANSACTION_CODE                                             S
# DRUG_CODE                                                 9193
# NDC_NO                                             12634051471
# DRUG_NAME                                          HYDROCODONE
# QUANTITY                                                    40
# UNIT                                                       NaN
# ACTION_INDICATOR                                           NaN
# ORDER_FORM_NO                                              NaN
# CORRECTION_NO                                              NaN
# STRENGTH                                                   NaN
# TRANSACTION_DATE                                      11252008
# CALC_BASE_WT_IN_GM                                      3.6324
# DOSAGE_UNIT                                               1200
# TRANSACTION_ID                                             119
# Product_Name              HYDROCODONE BITARTRATE & ACETA  5MG/
# Ingredient_Name        HYDROCODONE BITARTRATE HEMIPENTAHYDRATE
# Measure                                                    TAB
# MME_Conversion_Factor                                        1
# Combined_Labeler_Name                            Apotheca Inc.
# Revised_Company_Name                             Apotheca Inc.
# Reporter_family                                   Apotheca Inc
# dos_str                                                      5
# reporter id                                          PA0021179
#
#                                                             3   \
# REPORTER_DEA_NO                                      PA0021179
# REPORTER_BUS_ACT                                   DISTRIBUTOR
# REPORTER_NAME                                     APOTHECA INC
# REPORTER_ADDL_CO_INFO                                      NaN
# REPORTER_ADDRESS1                               1622 N 16TH ST
# REPORTER_ADDRESS2                                          NaN
# REPORTER_CITY                                          PHOENIX
# REPORTER_STATE                                              AZ
# REPORTER_ZIP                                             85006
# REPORTER_COUNTY                                       MARICOPA
# BUYER_DEA_NO                                         BH5651155
# BUYER_BUS_ACT                                     PRACTITIONER
# BUYER_NAME                             HOBBS, DOUGLAS DON,  MD
# BUYER_ADDL_CO_INFO                                         NaN
# BUYER_ADDRESS1                        URGENT CARE EXTRA COOPER
# BUYER_ADDRESS2                                 641 WEST WARNER
# BUYER_CITY                                             GILBERT
# BUYER_STATE                                                 AZ
# BUYER_ZIP                                                85233
# BUYER_COUNTY                                          MARICOPA
# TRANSACTION_CODE                                             S
# DRUG_CODE                                                 9193
# NDC_NO                                             12634078371
# DRUG_NAME                                          HYDROCODONE
# QUANTITY                                                    20
# UNIT                                                       NaN
# ACTION_INDICATOR                                           NaN
# ORDER_FORM_NO                                              NaN
# CORRECTION_NO                                              NaN
# STRENGTH                                                   NaN
# TRANSACTION_DATE                                       6122009
# CALC_BASE_WT_IN_GM                                      2.7243
# DOSAGE_UNIT                                                600
# TRANSACTION_ID                                              34
# Product_Name              HYDROCODONEBITARTRATE & ACETA  7.5MG
# Ingredient_Name        HYDROCODONE BITARTRATE HEMIPENTAHYDRATE
# Measure                                                    TAB
# MME_Conversion_Factor                                        1
# Combined_Labeler_Name                            Apotheca Inc.
# Revised_Company_Name                             Apotheca Inc.
# Reporter_family                                   Apotheca Inc
# dos_str                                                    7.5
# reporter id                                          PA0021179
#
#                                                             4   \
# REPORTER_DEA_NO                                      PA0021179
# REPORTER_BUS_ACT                                   DISTRIBUTOR
# REPORTER_NAME                                     APOTHECA INC
# REPORTER_ADDL_CO_INFO                                      NaN
# REPORTER_ADDRESS1                               1622 N 16TH ST
# REPORTER_ADDRESS2                                          NaN
# REPORTER_CITY                                          PHOENIX
# REPORTER_STATE                                              AZ
# REPORTER_ZIP                                             85006
# REPORTER_COUNTY                                       MARICOPA
# BUYER_DEA_NO                                         BH5651155
# BUYER_BUS_ACT                                     PRACTITIONER
# BUYER_NAME                             HOBBS, DOUGLAS DON,  MD
# BUYER_ADDL_CO_INFO                                         NaN
# BUYER_ADDRESS1                        URGENT CARE EXTRA COOPER
# BUYER_ADDRESS2                                 641 WEST WARNER
# BUYER_CITY                                             GILBERT
# BUYER_STATE                                                 AZ
# BUYER_ZIP                                                85233
# BUYER_COUNTY                                          MARICOPA
# TRANSACTION_CODE                                             S
# DRUG_CODE                                                 9193
# NDC_NO                                             12634051471
# DRUG_NAME                                          HYDROCODONE
# QUANTITY                                                    10
# UNIT                                                       NaN
# ACTION_INDICATOR                                           NaN
# ORDER_FORM_NO                                              NaN
# CORRECTION_NO                                              NaN
# STRENGTH                                                   NaN
# TRANSACTION_DATE                                      10022009
# CALC_BASE_WT_IN_GM                                      0.9081
# DOSAGE_UNIT                                                300
# TRANSACTION_ID                                              19
# Product_Name              HYDROCODONE BITARTRATE & ACETA  5MG/
# Ingredient_Name        HYDROCODONE BITARTRATE HEMIPENTAHYDRATE
# Measure                                                    TAB
# MME_Conversion_Factor                                        1
# Combined_Labeler_Name                            Apotheca Inc.
# Revised_Company_Name                             Apotheca Inc.
# Reporter_family                                   Apotheca Inc
# dos_str                                                      5
# reporter id                                          PA0021179
#
#                                                             5   \
# REPORTER_DEA_NO                                      PA0021179
# REPORTER_BUS_ACT                                   DISTRIBUTOR
# REPORTER_NAME                                     APOTHECA INC
# REPORTER_ADDL_CO_INFO                                      NaN
# REPORTER_ADDRESS1                               1622 N 16TH ST
# REPORTER_ADDRESS2                                          NaN
# REPORTER_CITY                                          PHOENIX
# REPORTER_STATE                                              AZ
# REPORTER_ZIP                                             85006
# REPORTER_COUNTY                                       MARICOPA
# BUYER_DEA_NO                                         BH5651155
# BUYER_BUS_ACT                                     PRACTITIONER
# BUYER_NAME                             HOBBS, DOUGLAS DON,  MD
# BUYER_ADDL_CO_INFO                                         NaN
# BUYER_ADDRESS1                        URGENT CARE EXTRA COOPER
# BUYER_ADDRESS2                                 641 WEST WARNER
# BUYER_CITY                                             GILBERT
# BUYER_STATE                                                 AZ
# BUYER_ZIP                                                85233
# BUYER_COUNTY                                          MARICOPA
# TRANSACTION_CODE                                             S
# DRUG_CODE                                                 9193
# NDC_NO                                             12634051471
# DRUG_NAME                                          HYDROCODONE
# QUANTITY                                                    20
# UNIT                                                       NaN
# ACTION_INDICATOR                                           NaN
# ORDER_FORM_NO                                              NaN
# CORRECTION_NO                                              NaN
# STRENGTH                                                   NaN
# TRANSACTION_DATE                                       3232010
# CALC_BASE_WT_IN_GM                                      1.8162
# DOSAGE_UNIT                                                600
# TRANSACTION_ID                                              73
# Product_Name              HYDROCODONE BITARTRATE & ACETA  5MG/
# Ingredient_Name        HYDROCODONE BITARTRATE HEMIPENTAHYDRATE
# Measure                                                    TAB
# MME_Conversion_Factor                                        1
# Combined_Labeler_Name                            Apotheca Inc.
# Revised_Company_Name                             Apotheca Inc.
# Reporter_family                                   Apotheca Inc
# dos_str                                                      5
# reporter id                                          PA0021179
#
#                                                             6   \
# REPORTER_DEA_NO                                      PA0021179
# REPORTER_BUS_ACT                                   DISTRIBUTOR
# REPORTER_NAME                                     APOTHECA INC
# REPORTER_ADDL_CO_INFO                                      NaN
# REPORTER_ADDRESS1                               1622 N 16TH ST
# REPORTER_ADDRESS2                                          NaN
# REPORTER_CITY                                          PHOENIX
# REPORTER_STATE                                              AZ
# REPORTER_ZIP                                             85006
# REPORTER_COUNTY                                       MARICOPA
# BUYER_DEA_NO                                         BJ5858002
# BUYER_BUS_ACT                                     PRACTITIONER
# BUYER_NAME                              JEFFERS, WILL VAHID DO
# BUYER_ADDL_CO_INFO                                    NOW CARE
# BUYER_ADDRESS1                           8251 W UNION HILLS DR
# BUYER_ADDRESS2                                       SUITE 140
# BUYER_CITY                                            GLENDALE
# BUYER_STATE                                                 AZ
# BUYER_ZIP                                                85308
# BUYER_COUNTY                                          MARICOPA
# TRANSACTION_CODE                                             S
# DRUG_CODE                                                 9193
# NDC_NO                                             12634051485
# DRUG_NAME                                          HYDROCODONE
# QUANTITY                                                     5
# UNIT                                                       NaN
# ACTION_INDICATOR                                           NaN
# ORDER_FORM_NO                                              NaN
# CORRECTION_NO                                              NaN
# STRENGTH                                                   NaN
# TRANSACTION_DATE                                      10112007
# CALC_BASE_WT_IN_GM                                    0.227025
# DOSAGE_UNIT                                                 75
# TRANSACTION_ID                                              58
# Product_Name              HYDROCODONE BITARTRATE & ACETA  5MG/
# Ingredient_Name        HYDROCODONE BITARTRATE HEMIPENTAHYDRATE
# Measure                                                    TAB
# MME_Conversion_Factor                                        1
# Combined_Labeler_Name                            Apotheca Inc.
# Revised_Company_Name                             Apotheca Inc.
# Reporter_family                                   Apotheca Inc
# dos_str                                                      5
# reporter id                                          PA0021179
#
#                                                             7   \
# REPORTER_DEA_NO                                      PA0021179
# REPORTER_BUS_ACT                                   DISTRIBUTOR
# REPORTER_NAME                                     APOTHECA INC
# REPORTER_ADDL_CO_INFO                                      NaN
# REPORTER_ADDRESS1                               1622 N 16TH ST
# REPORTER_ADDRESS2                                          NaN
# REPORTER_CITY                                          PHOENIX
# REPORTER_STATE                                              AZ
# REPORTER_ZIP                                             85006
# REPORTER_COUNTY                                       MARICOPA
# BUYER_DEA_NO                                         BJ5858002
# BUYER_BUS_ACT                                     PRACTITIONER
# BUYER_NAME                              JEFFERS, WILL VAHID DO
# BUYER_ADDL_CO_INFO                                    NOW CARE
# BUYER_ADDRESS1                           8251 W UNION HILLS DR
# BUYER_ADDRESS2                                       SUITE 140
# BUYER_CITY                                            GLENDALE
# BUYER_STATE                                                 AZ
# BUYER_ZIP                                                85308
# BUYER_COUNTY                                          MARICOPA
# TRANSACTION_CODE                                             S
# DRUG_CODE                                                 9193
# NDC_NO                                             12634051485
# DRUG_NAME                                          HYDROCODONE
# QUANTITY                                                    10
# UNIT                                                       NaN
# ACTION_INDICATOR                                           NaN
# ORDER_FORM_NO                                              NaN
# CORRECTION_NO                                              NaN
# STRENGTH                                                   NaN
# TRANSACTION_DATE                                       1112008
# CALC_BASE_WT_IN_GM                                     0.45405
# DOSAGE_UNIT                                                150
# TRANSACTION_ID                                              79
# Product_Name              HYDROCODONE BITARTRATE & ACETA  5MG/
# Ingredient_Name        HYDROCODONE BITARTRATE HEMIPENTAHYDRATE
# Measure                                                    TAB
# MME_Conversion_Factor                                        1
# Combined_Labeler_Name                            Apotheca Inc.
# Revised_Company_Name                             Apotheca Inc.
# Reporter_family                                   Apotheca Inc
# dos_str                                                      5
# reporter id                                          PA0021179
#
#                                                             8   \
# REPORTER_DEA_NO                                      PA0021179
# REPORTER_BUS_ACT                                   DISTRIBUTOR
# REPORTER_NAME                                     APOTHECA INC
# REPORTER_ADDL_CO_INFO                                      NaN
# REPORTER_ADDRESS1                               1622 N 16TH ST
# REPORTER_ADDRESS2                                          NaN
# REPORTER_CITY                                          PHOENIX
# REPORTER_STATE                                              AZ
# REPORTER_ZIP                                             85006
# REPORTER_COUNTY                                       MARICOPA
# BUYER_DEA_NO                                         BJ5858002
# BUYER_BUS_ACT                                     PRACTITIONER
# BUYER_NAME                              JEFFERS, WILL VAHID DO
# BUYER_ADDL_CO_INFO                                    NOW CARE
# BUYER_ADDRESS1                           8251 W UNION HILLS DR
# BUYER_ADDRESS2                                       SUITE 140
# BUYER_CITY                                            GLENDALE
# BUYER_STATE                                                 AZ
# BUYER_ZIP                                                85308
# BUYER_COUNTY                                          MARICOPA
# TRANSACTION_CODE                                             S
# DRUG_CODE                                                 9193
# NDC_NO                                             12634051485
# DRUG_NAME                                          HYDROCODONE
# QUANTITY                                                    10
# UNIT                                                       NaN
# ACTION_INDICATOR                                           NaN
# ORDER_FORM_NO                                              NaN
# CORRECTION_NO                                              NaN
# STRENGTH                                                   NaN
# TRANSACTION_DATE                                       7142008
# CALC_BASE_WT_IN_GM                                     0.45405
# DOSAGE_UNIT                                                150
# TRANSACTION_ID                                              65
# Product_Name              HYDROCODONE BITARTRATE & ACETA  5MG/
# Ingredient_Name        HYDROCODONE BITARTRATE HEMIPENTAHYDRATE
# Measure                                                    TAB
# MME_Conversion_Factor                                        1
# Combined_Labeler_Name                            Apotheca Inc.
# Revised_Company_Name                             Apotheca Inc.
# Reporter_family                                   Apotheca Inc
# dos_str                                                      5
# reporter id                                          PA0021179
#
#                                                             9   \
# REPORTER_DEA_NO                                      PA0021179
# REPORTER_BUS_ACT                                   DISTRIBUTOR
# REPORTER_NAME                                     APOTHECA INC
# REPORTER_ADDL_CO_INFO                                      NaN
# REPORTER_ADDRESS1                               1622 N 16TH ST
# REPORTER_ADDRESS2                                          NaN
# REPORTER_CITY                                          PHOENIX
# REPORTER_STATE                                              AZ
# REPORTER_ZIP                                             85006
# REPORTER_COUNTY                                       MARICOPA
# BUYER_DEA_NO                                         BJ5858002
# BUYER_BUS_ACT                                     PRACTITIONER
# BUYER_NAME                              JEFFERS, WILL VAHID DO
# BUYER_ADDL_CO_INFO                                    NOW CARE
# BUYER_ADDRESS1                           8251 W UNION HILLS DR
# BUYER_ADDRESS2                                       SUITE 140
# BUYER_CITY                                            GLENDALE
# BUYER_STATE                                                 AZ
# BUYER_ZIP                                                85308
# BUYER_COUNTY                                          MARICOPA
# TRANSACTION_CODE                                             S
# DRUG_CODE                                                 9193
# NDC_NO                                             12634051485
# DRUG_NAME                                          HYDROCODONE
# QUANTITY                                                    10
# UNIT                                                       NaN
# ACTION_INDICATOR                                           NaN
# ORDER_FORM_NO                                              NaN
# CORRECTION_NO                                              NaN
# STRENGTH                                                   NaN
# TRANSACTION_DATE                                      12052012
# CALC_BASE_WT_IN_GM                                     0.45405
# DOSAGE_UNIT                                                150
# TRANSACTION_ID                                               5
# Product_Name              HYDROCODONE BITARTRATE & ACETA  5MG/
# Ingredient_Name        HYDROCODONE BITARTRATE HEMIPENTAHYDRATE
# Measure                                                    TAB
# MME_Conversion_Factor                                        1
# Combined_Labeler_Name                            Apotheca Inc.
# Revised_Company_Name                             Apotheca Inc.
# Reporter_family                                   Apotheca Inc
# dos_str                                                      5
# reporter id                                          PA0021179
#
#                                                             10  \
# REPORTER_DEA_NO                                      PA0021179
# REPORTER_BUS_ACT                                   DISTRIBUTOR
# REPORTER_NAME                                     APOTHECA INC
# REPORTER_ADDL_CO_INFO                                      NaN
# REPORTER_ADDRESS1                               1622 N 16TH ST
# REPORTER_ADDRESS2                                          NaN
# REPORTER_CITY                                          PHOENIX
# REPORTER_STATE                                              AZ
# REPORTER_ZIP                                             85006
# REPORTER_COUNTY                                       MARICOPA
# BUYER_DEA_NO                                         BK7485863
# BUYER_BUS_ACT                              PRACTITIONER-DW/275
# BUYER_NAME                                    KHOURY, MUFID MD
# BUYER_ADDL_CO_INFO                                         NaN
# BUYER_ADDRESS1                      6220 W BELL ROAD SUITE 100
# BUYER_ADDRESS2                                             NaN
# BUYER_CITY                                            GLENDALE
# BUYER_STATE                                                 AZ
# BUYER_ZIP                                                85308
# BUYER_COUNTY                                          MARICOPA
# TRANSACTION_CODE                                             S
# DRUG_CODE                                                 9193
# NDC_NO                                             12634051480
# DRUG_NAME                                          HYDROCODONE
# QUANTITY                                                    10
# UNIT                                                       NaN
# ACTION_INDICATOR                                           NaN
# ORDER_FORM_NO                                              NaN
# CORRECTION_NO                                              NaN
# STRENGTH                                                   NaN
# TRANSACTION_DATE                                       7242012
# CALC_BASE_WT_IN_GM                                      0.6054
# DOSAGE_UNIT                                                200
# TRANSACTION_ID                                              64
# Product_Name              HYDROCODONE BITARTRATE & ACETA  5MG/
# Ingredient_Name        HYDROCODONE BITARTRATE HEMIPENTAHYDRATE
# Measure                                                    TAB
# MME_Conversion_Factor                                        1
# Combined_Labeler_Name                            Apotheca Inc.
# Revised_Company_Name                             Apotheca Inc.
# Reporter_family                                   Apotheca Inc
# dos_str                                                      5
# reporter id                                          PA0021179
#
#                                                             11  \
# REPORTER_DEA_NO                                      PA0021179
# REPORTER_BUS_ACT                                   DISTRIBUTOR
# REPORTER_NAME                                     APOTHECA INC
# REPORTER_ADDL_CO_INFO                                      NaN
# REPORTER_ADDRESS1                               1622 N 16TH ST
# REPORTER_ADDRESS2                                          NaN
# REPORTER_CITY                                          PHOENIX
# REPORTER_STATE                                              AZ
# REPORTER_ZIP                                             85006
# REPORTER_COUNTY                                       MARICOPA
# BUYER_DEA_NO                                         BL2528404
# BUYER_BUS_ACT                                     PRACTITIONER
# BUYER_NAME                                 LEDERMAN, EVAN S MD
# BUYER_ADDL_CO_INFO                                         NaN
# BUYER_ADDRESS1                           2222 E. HIGHLAND AVE.
# BUYER_ADDRESS2                                       SUITE 300
# BUYER_CITY                                             PHOENIX
# BUYER_STATE                                                 AZ
# BUYER_ZIP                                                85016
# BUYER_COUNTY                                          MARICOPA
# TRANSACTION_CODE                                             S
# DRUG_CODE                                                 9193
# NDC_NO                                             12634078371
# DRUG_NAME                                          HYDROCODONE
# QUANTITY                                                    10
# UNIT                                                       NaN
# ACTION_INDICATOR                                           NaN
# ORDER_FORM_NO                                              NaN
# CORRECTION_NO                                              771
# STRENGTH                                                   NaN
# TRANSACTION_DATE                                       1072008
# CALC_BASE_WT_IN_GM                                     1.36215
# DOSAGE_UNIT                                                300
# TRANSACTION_ID                                              53
# Product_Name              HYDROCODONEBITARTRATE & ACETA  7.5MG
# Ingredient_Name        HYDROCODONE BITARTRATE HEMIPENTAHYDRATE
# Measure                                                    TAB
# MME_Conversion_Factor                                        1
# Combined_Labeler_Name                            Apotheca Inc.
# Revised_Company_Name                             Apotheca Inc.
# Reporter_family                                   Apotheca Inc
# dos_str                                                    7.5
# reporter id                                          PA0021179
#
#                                                             12  \
# REPORTER_DEA_NO                                      PA0021179
# REPORTER_BUS_ACT                                   DISTRIBUTOR
# REPORTER_NAME                                     APOTHECA INC
# REPORTER_ADDL_CO_INFO                                      NaN
# REPORTER_ADDRESS1                               1622 N 16TH ST
# REPORTER_ADDRESS2                                          NaN
# REPORTER_CITY                                          PHOENIX
# REPORTER_STATE                                              AZ
# REPORTER_ZIP                                             85006
# REPORTER_COUNTY                                       MARICOPA
# BUYER_DEA_NO                                         BN9327859
# BUYER_BUS_ACT                                     PRACTITIONER
# BUYER_NAME                                 NUCATOLA, DEBORAH L
# BUYER_ADDL_CO_INFO                                         NaN
# BUYER_ADDRESS1                             5400 RALSTON STREET
# BUYER_ADDRESS2                                             NaN
# BUYER_CITY                                             VENTURA
# BUYER_STATE                                                 CA
# BUYER_ZIP                                                93003
# BUYER_COUNTY                                           VENTURA
# TRANSACTION_CODE                                             S
# DRUG_CODE                                                 9193
# NDC_NO                                             12634051400
# DRUG_NAME                                          HYDROCODONE
# QUANTITY                                                    20
# UNIT                                                       NaN
# ACTION_INDICATOR                                           NaN
# ORDER_FORM_NO                                              NaN
# CORRECTION_NO                                              NaN
# STRENGTH                                                   NaN
# TRANSACTION_DATE                                       2092007
# CALC_BASE_WT_IN_GM                                      0.6054
# DOSAGE_UNIT                                                200
# TRANSACTION_ID                                              30
# Product_Name              HYDROCODONE BITARTRATE & ACETA  5MG/
# Ingredient_Name        HYDROCODONE BITARTRATE HEMIPENTAHYDRATE
# Measure                                                    TAB
# MME_Conversion_Factor                                        1
# Combined_Labeler_Name                            Apotheca Inc.
# Revised_Company_Name                             Apotheca Inc.
# Reporter_family                                   Apotheca Inc
# dos_str                                                      5
# reporter id                                          PA0021179
#
#                                                             13  \
# REPORTER_DEA_NO                                      PA0021179
# REPORTER_BUS_ACT                                   DISTRIBUTOR
# REPORTER_NAME                                     APOTHECA INC
# REPORTER_ADDL_CO_INFO                                      NaN
# REPORTER_ADDRESS1                               1622 N 16TH ST
# REPORTER_ADDRESS2                                          NaN
# REPORTER_CITY                                          PHOENIX
# REPORTER_STATE                                              AZ
# REPORTER_ZIP                                             85006
# REPORTER_COUNTY                                       MARICOPA
# BUYER_DEA_NO                                         BS7305039
# BUYER_BUS_ACT                                     PRACTITIONER
# BUYER_NAME                                 SAWYER, JEFFRY S MD
# BUYER_ADDL_CO_INFO                                         NaN
# BUYER_ADDRESS1                              5615 S SOSSAMAN RD
# BUYER_ADDRESS2                                             NaN
# BUYER_CITY                                                MESA
# BUYER_STATE                                                 AZ
# BUYER_ZIP                                                85212
# BUYER_COUNTY                                          MARICOPA
# TRANSACTION_CODE                                             S
# DRUG_CODE                                                 9193
# NDC_NO                                             12634051471
# DRUG_NAME                                          HYDROCODONE
# QUANTITY                                                    40
# UNIT                                                       NaN
# ACTION_INDICATOR                                           NaN
# ORDER_FORM_NO                                              NaN
# CORRECTION_NO                                              NaN
# STRENGTH                                                   NaN
# TRANSACTION_DATE                                       9122007
# CALC_BASE_WT_IN_GM                                      3.6324
# DOSAGE_UNIT                                               1200
# TRANSACTION_ID                                              68
# Product_Name              HYDROCODONE BITARTRATE & ACETA  5MG/
# Ingredient_Name        HYDROCODONE BITARTRATE HEMIPENTAHYDRATE
# Measure                                                    TAB
# MME_Conversion_Factor                                        1
# Combined_Labeler_Name                            Apotheca Inc.
# Revised_Company_Name                             Apotheca Inc.
# Reporter_family                                   Apotheca Inc
# dos_str                                                      5
# reporter id                                          PA0021179
#
#                                                             14
# REPORTER_DEA_NO                                      PA0021179
# REPORTER_BUS_ACT                                   DISTRIBUTOR
# REPORTER_NAME                                     APOTHECA INC
# REPORTER_ADDL_CO_INFO                                      NaN
# REPORTER_ADDRESS1                               1622 N 16TH ST
# REPORTER_ADDRESS2                                          NaN
# REPORTER_CITY                                          PHOENIX
# REPORTER_STATE                                              AZ
# REPORTER_ZIP                                             85006
# REPORTER_COUNTY                                       MARICOPA
# BUYER_DEA_NO                                         BS7305039
# BUYER_BUS_ACT                                     PRACTITIONER
# BUYER_NAME                                 SAWYER, JEFFRY S MD
# BUYER_ADDL_CO_INFO                                         NaN
# BUYER_ADDRESS1                              5615 S SOSSAMAN RD
# BUYER_ADDRESS2                                             NaN
# BUYER_CITY                                                MESA
# BUYER_STATE                                                 AZ
# BUYER_ZIP                                                85212
# BUYER_COUNTY                                          MARICOPA
# TRANSACTION_CODE                                             S
# DRUG_CODE                                                 9193
# NDC_NO                                             12634051471
# DRUG_NAME                                          HYDROCODONE
# QUANTITY                                                    20
# UNIT                                                       NaN
# ACTION_INDICATOR                                           NaN
# ORDER_FORM_NO                                              NaN
# CORRECTION_NO                                              NaN
# STRENGTH                                                   NaN
# TRANSACTION_DATE                                      11072008
# CALC_BASE_WT_IN_GM                                      1.8162
# DOSAGE_UNIT                                                600
# TRANSACTION_ID                                              23
# Product_Name              HYDROCODONE BITARTRATE & ACETA  5MG/
# Ingredient_Name        HYDROCODONE BITARTRATE HEMIPENTAHYDRATE
# Measure                                                    TAB
# MME_Conversion_Factor                                        1
# Combined_Labeler_Name                            Apotheca Inc.
# Revised_Company_Name                             Apotheca Inc.
# Reporter_family                                   Apotheca Inc
# dos_str                                                      5
# reporter id                                          PA0021179

# %%
# some of this data will get pretty big;
# it will be important to practice dropping unused data.
del temp_data

# %% [markdown]
# ### Outlining Data Columns
# There's many columns here.
# It will be important to outline what each of them actually represent.
# Some of these are actually self-explanatory, but others might make do with some greater understanding.
#
# #### Important Terminology
# - **DEA**: Drug Enforcement Administration
# - **NDC**: National Drug Code
# - **BUS_ACT**: Seems to stand for business activity.
# - **NO**: Number
# - **ADDL_CO_INFO**: Additional Contact Information
# - **MME**: Morphine Milligram Equivalent
#
# #### Column Descriptions
# - REPORTER_DEA_NO
# 	- appears to be a unique identifier for a buyer or reporter.
# - REPORTER_BUS_ACT
# 	- appears to be a class of reporter.
# 		options include:
# 		- DISTRIBUTOR
# 		- MANUFACTURER
# 		- REVERSE DISTRIB
# - ~~REPORTER_NAME~~
# - ~~REPORTER_ADDL_CO_INFO~~
# - ~~REPORTER_ADDRESS1~~
# - ~~REPORTER_ADDRESS2~~
# - ~~REPORTER_CITY~~
# - ~~REPORTER_STATE~~
# - ~~REPORTER_ZIP~~
# - ~~REPORTER_COUNTY~~
# - BUYER_DEA_NO
# 	- appears to be a unique identifier for a buyer or reporter.
# - BUYER_BUS_ACT
# 	- appears to be a class of buyer.
# 		options include:
# 		- CHAIN PHARMACY
# 		- RETAIL PHARMACY
# 		- PRACTITIONER
# - ~~BUYER_NAME~~
# - ~~BUYER_ADDL_CO_INFO~~
# - ~~BUYER_ADDRESS1~~
# - ~~BUYER_ADDRESS2~~
# - ~~BUYER_CITY~~
# - ~~BUYER_STATE~~
# - ~~BUYER_ZIP~~
# - ~~BUYER_COUNTY~~
# - TRANSACTION_CODE
# 	- Inventory Transaction Codes
# 		- 1: Schedule Change Inventory
# 		- 3: Year-End Inventory
# 		- 4: Year-End In-Process Inventory (manufacturers only)
# 		- 5: Special Inventory
# 		- 8: No Year-End Inventory
# 	- Acquisition Transaction Codes (Increases to Inventory)
# 		- P: Purchase or Receipt
# 		- R: Return
# 		- V: Unsolicited Return
# 		- G: Government Supplied
# 		- W: Recovered Waste (manufacturers only)
# 		- M: Manufactured (manufacturers only)
# 		- L: Reversing (manufacturers only)
# 		- J: Return of Sample to Inventory (manufacturers only)
# 	- Disposition Transaction Codes (Decreases to Inventory)
# 		- S: Sale, Disposition, or Transfer
# 		- Y: Destroyed
# 		- T: Theft
# 		- Z: Receipt by Government (seizures, samples, etc.)
# 		- N: Nonrecoverable Waste (manufacturers only)
# 		- U: Used in Production (manufacturers only)
# 		- Q: Sampling (manufacturers only)
# 		- K: Used in Preparations (manufacturers only)
# 	- Miscellaneous Transaction Codes
# 		- 7: No ARCOS Activity for the Current Reporting Period
# 		- F: Reorder DEA Form 333
# 		- X: Lost-in-Transit
# - DRUG_CODE
# 	- this entry seems to line up with the drug name.
# 		it might function as some sort of low-level identifier, much like a upc.
# - NDC_NO
# 	- this entry seems to line up with the product name.
# 		it might function as some sort of low-level identifier, much like a upc.
# - DRUG_NAME
# 	- this entry lines up with ingredient name.
# - QUANTITY
# 	- most likely, this is the number of units purchased.
# - UNIT
# 	- `WARNING` unfortunately, this appears to be a junk column.
# - ACTION_INDICATOR
# 	- D: delete a transaction record
# 	- A: adjust (revise) data in a transaction record
# 	- I: insert (add) a late transaction record
# - ORDER_FORM_NO
# 	- most likely, this is some sort of identifier for a class of form.
# 		note that only OXYCODONE drugs require/have a form entry.
# 		HYDROCODONE does not use these forms.
# - CORRECTION_NO
# 	- `WARNING` unfortunately, this appears to be a junk column.
# - STRENGTH
# 	- `WARNING` unfortunately, this appears to be a junk column.
# - ~~TRANSACTION_DATE~~
# - CALC_BASE_WT_IN_GM
# 	- this seems to be a calculated column.
# 		if we can determine what the formula was for this, we can delete this entry.
# - DOSAGE_UNIT
# 	- seems to be the number of mg of drugs that the tablet contains.
# - TRANSACTION_ID
# - Product_Name
# 	- the shelf name for the product.
# - Ingredient_Name
# 	- the long-form chemical name for the product.
# - Measure
# 	- because all entries are "tab", it seems like this refers to the drug being a "tablet".
# - MME_Conversion_Factor
# 	- Morphine Milligram Equivalent
# - Combined_Labeler_Name
# 	- seems like some sort of label company for the product itself.
# - Revised_Company_Name
# 	- seems like some sort of parent company for the product itself.
# - Reporter_family
# 	- seems like the umbrella company that reported this entry.
# - dos_str
# 	- number of milligrams of the drug in a capsule

# %% [markdown]
# ## Prep Data

# %% [markdown]
# ## Clean Data

# %%
# create a dictionary of current column names,
# and match them with new, simplified titles
columns_to_rename = {
	'REPORTER_DEA_NO':       'reporter id',
	'REPORTER_BUS_ACT':      'reporter business activity',
	'REPORTER_NAME':         'reporter name',
	'REPORTER_ADDL_CO_INFO': 'reporter contact information',
	'REPORTER_ADDRESS1':     'reporter address 1',
	'REPORTER_ADDRESS2':     'reporter address 2',
	'REPORTER_CITY':         'reporter city',
	'REPORTER_STATE':        'reporter state',
	'REPORTER_ZIP':          'reporter zip',
	'REPORTER_COUNTY':       'reporter county',
	'BUYER_DEA_NO':          'buyer id',
	'BUYER_BUS_ACT':         'buyer business activity',
	'BUYER_NAME':            'buyer name',
	'BUYER_ADDL_CO_INFO':    'buyer contact information',
	'BUYER_ADDRESS1':        'buyer address 1',
	'BUYER_ADDRESS2':        'buyer address 2',
	'BUYER_CITY':            'buyer city',
	'BUYER_STATE':           'buyer state',
	'BUYER_ZIP':             'buyer zip',
	'BUYER_COUNTY':          'buyer county',
	'TRANSACTION_CODE':      'transaction code',
	'DRUG_CODE':             'drug code',
	'NDC_NO':                'national drug code',
	'DRUG_NAME':             'drug name',
	'QUANTITY':              'quantity',
	'UNIT':                  'unit',
	'ACTION_INDICATOR':      'action item',
	'ORDER_FORM_NO':         'form number',
	'CORRECTION_NO':         'correction number',
	'STRENGTH':              'junk strength',
	'TRANSACTION_DATE':      'transaction date',
	'CALC_BASE_WT_IN_GM':    'weight (grams)',
	'DOSAGE_UNIT':           'order size',
	'TRANSACTION_ID':        'transaction id',
	'Product_Name':          'product name',
	'Ingredient_Name':       'ingredient name',
	'Measure':               'drug form',
	'MME_Conversion_Factor': 'morphine milligram equivalent',
	'Combined_Labeler_Name': 'labeler name',
	'Revised_Company_Name':  'company name',
	'Reporter_family':       'reporter family',
	'dos_str':               'strength (mg)'
}

# %%
# create a set of current column names,
# these are columns that we want to delete
columns_to_delete = {
	# 'reporter id',
	# 'reporter business activity',
	# 'reporter name',
	# 'reporter contact information',
	# 'reporter address 1',
	# 'reporter address 2',
	# 'reporter city',
	# 'reporter state',
	# 'reporter zip',
	# 'reporter county',
	# 'buyer id',
	# 'buyer business activity',
	# 'buyer name',
	# 'buyer contact information',
	# 'buyer address 1',
	# 'buyer address 2',
	# 'buyer city',
	# 'buyer state',
	# 'buyer zip',
	# 'buyer county',
	# 'transaction code',
	# 'drug code',
	# 'national drug code',
	# 'drug name',
	# 'quantity',
	# 'unit',
	# 'action item',
	# 'form number',
	# 'correction number',
	# 'junk strength',
	# 'transaction date',
	# 'weight (grams)',
	# 'order size',
	# 'transaction id',
	# 'product name',
	# 'ingredient name',
	# 'drug form',
	# 'morphine milligram equivalent',
	# 'labeler name',
	# 'company name',
	# 'reporter family',
	# 'strength (mg)'
}

# %%
def rename_column(dataframe, old_name, new_name):
	dataframe[new_name] = dataframe[old_name]
	dataframe = dataframe.drop([old_name], 1)
	return dataframe

def rename_columns_by_dictionary(dataframe, dictionary):
	for key in dictionary:
		old_name = key
		new_name = dictionary[key]
		dataframe = rename_column(dataframe, old_name, new_name)
	return dataframe

data = rename_columns_by_dictionary(data, columns_to_rename)

# %%
def delete_column(dataframe, del_name):
	dataframe = dataframe.drop([del_name], 1)
	return dataframe

def delete_columns_by_array(dataframe, array):
	for item in array:
		del_name = item
		dataframe = delete_column(dataframe, del_name)
	return dataframe

data = delete_columns_by_array(data, columns_to_delete)
